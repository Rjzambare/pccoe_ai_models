# %%
pip install PyMuPDF pytesseract Pillow spacy transformers
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.11-cp38-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: Pillow in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (11.0.0)
# Collecting spacy
#   Downloading spacy-3.8.2-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting transformers
#   Downloading transformers-4.45.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\rohit\appdata\roaming\python\python312\site-packages (from pytesseract) (24.1)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.4.0,>=8.3.0 (from spacy)
#   Downloading thinc-8.3.2-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting jinja2 (from spacy)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting setuptools (from spacy)
#   Downloading setuptools-75.2.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.1.2)
# Collecting filelock (from transformers)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers)
#   Downloading huggingface_hub-0.26.0-py3-none-any.whl.metadata (13 kB)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.9.11-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.5-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Downloading tokenizers-0.20.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.23.2->transformers)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub<1.0,>=0.23.2->transformers)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting blis<1.1.0,>=1.0.0 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading blis-1.0.1-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: colorama in c:\users\rohit\appdata\roaming\python\python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading rich-13.9.2-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.0.5-py3-none-any.whl.metadata (24 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohit\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading PyMuPDF-1.24.11-cp38-abi3-win_amd64.whl (16.0 MB)
#    ---------------------------------------- 0.0/16.0 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/16.0 MB 10.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/16.0 MB 11.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.1/16.0 MB 10.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/16.0 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.8/16.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.9/16.0 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  15.7/16.0 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 16.0/16.0 MB 10.3 MB/s eta 0:00:00
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Downloading spacy-3.8.2-cp312-cp312-win_amd64.whl (11.8 MB)
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.8 MB 10.7 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.8 MB 10.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.8 MB 10.9 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.8 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.8/11.8 MB 10.7 MB/s eta 0:00:00
# Downloading transformers-4.45.2-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.9 MB 11.8 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.9 MB 11.7 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.6 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl (39 kB)
# Downloading huggingface_hub-0.26.0-py3-none-any.whl (447 kB)
# Downloading langcodes-3.4.1-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl (122 kB)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 11.7 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Downloading regex-2024.9.11-cp312-cp312-win_amd64.whl (273 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading safetensors-0.4.5-cp312-none-win_amd64.whl (286 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl (478 kB)
# Downloading thinc-8.3.2-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 9.5 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ------ --------------------------------- 2.4/15.6 MB 11.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.6 MB 11.2 MB/s eta 0:00:01
#    ------------------ --------------------- 7.1/15.6 MB 11.5 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.6 MB 11.5 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.6 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.6 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.6 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 9.9 MB/s eta 0:00:00
# Downloading tokenizers-0.20.1-cp312-none-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 10.4 MB/s eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading setuptools-75.2.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 10.6 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blis-1.0.1-cp312-cp312-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    -------------- ------------------------- 2.4/6.4 MB 12.2 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.4 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 11.2 MB/s eta 0:00:00
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    ----------------- ---------------------- 2.4/5.4 MB 11.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.7/5.4 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 10.9 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Downloading rich-13.9.2-py3-none-any.whl (242 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.0.5-py3-none-any.whl (61 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading marisa_trie-1.2.1-cp312-cp312-win_amd64.whl (150 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, shellingham, setuptools, safetensors, regex, pyyaml, pytesseract, PyMuPDF, numpy, murmurhash, mdurl, MarkupSafe, idna, fsspec, filelock, cloudpathlib, click, charset-normalizer, certifi, catalogue, annotated-types, srsly, smart-open, requests, pydantic-core, preshed, markdown-it-py, marisa-trie, jinja2, blis, rich, pydantic, language-data, huggingface-hub, typer, tokenizers, langcodes, confection, weasel, transformers, thinc, spacy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# Successfully installed MarkupSafe-3.0.2 PyMuPDF-1.24.11 annotated-types-0.7.0 blis-1.0.1 catalogue-2.0.10 certifi-2024.8.30 charset-normalizer-3.4.0 click-8.1.7 cloudpathlib-0.20.0 confection-0.1.5 cymem-2.0.8 filelock-3.16.1 fsspec-2024.9.0 huggingface-hub-0.26.0 idna-3.10 jinja2-3.1.4 langcodes-3.4.1 language-data-1.2.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 numpy-2.0.2 preshed-3.0.9 pydantic-2.9.2 pydantic-core-2.23.4 pytesseract-0.3.13 pyyaml-6.0.2 regex-2024.9.11 requests-2.32.3 rich-13.9.2 safetensors-0.4.5 setuptools-75.2.0 shellingham-1.5.4 smart-open-7.0.5 spacy-3.8.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.3.2 tokenizers-0.20.1 tqdm-4.66.5 transformers-4.45.2 typer-0.12.5 typing-extensions-4.12.2 urllib3-2.2.3 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdf2image torch
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting torch
#   Downloading torch-2.5.0-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: pillow in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from pdf2image) (11.0.0)
# Requirement already satisfied: filelock in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Collecting networkx (from torch)
#   Downloading networkx-3.4.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from torch) (75.2.0)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading torch-2.5.0-cp312-cp312-win_amd64.whl (203.1 MB)
#    ---------------------------------------- 0.0/203.1 MB ? eta -:--:--
#    ---------------------------------------- 2.4/203.1 MB 12.2 MB/s eta 0:00:17
#     --------------------------------------- 4.7/203.1 MB 11.9 MB/s eta 0:00:17
#    - -------------------------------------- 6.8/203.1 MB 11.0 MB/s eta 0:00:18
#    - -------------------------------------- 8.1/203.1 MB 9.7 MB/s eta 0:00:21
#    -- ------------------------------------- 10.2/203.1 MB 9.5 MB/s eta 0:00:21
#    -- ------------------------------------- 12.6/203.1 MB 9.9 MB/s eta 0:00:20
#    -- ------------------------------------- 14.9/203.1 MB 10.1 MB/s eta 0:00:19
#    --- ------------------------------------ 17.3/203.1 MB 10.3 MB/s eta 0:00:19
#    --- ------------------------------------ 19.9/203.1 MB 10.5 MB/s eta 0:00:18
#    ---- ----------------------------------- 22.3/203.1 MB 10.5 MB/s eta 0:00:18
#    ---- ----------------------------------- 24.6/203.1 MB 10.7 MB/s eta 0:00:17
#    ----- ---------------------------------- 27.3/203.1 MB 10.7 MB/s eta 0:00:17
#    ----- ---------------------------------- 29.6/203.1 MB 10.9 MB/s eta 0:00:16
#    ------ --------------------------------- 32.2/203.1 MB 10.9 MB/s eta 0:00:16
#    ------ --------------------------------- 34.6/203.1 MB 10.9 MB/s eta 0:00:16
#    ------- -------------------------------- 37.2/203.1 MB 11.0 MB/s eta 0:00:16
#    ------- -------------------------------- 39.6/203.1 MB 11.0 MB/s eta 0:00:15
#    -------- ------------------------------- 41.9/203.1 MB 11.1 MB/s eta 0:00:15
#    -------- ------------------------------- 44.3/203.1 MB 11.1 MB/s eta 0:00:15
#    --------- ------------------------------ 46.7/203.1 MB 11.1 MB/s eta 0:00:15
#    --------- ------------------------------ 49.3/203.1 MB 11.1 MB/s eta 0:00:14
#    ---------- -----------------------------
2 MB/s eta 0:00:06
#    ---------------------------- ---------- 148.1/203.1 MB 11.2 MB/s eta 0:00:05
#    ---------------------------- ---------- 150.5/203.1 MB 11.3 MB/s eta 0:00:05
#    ----------------------------- --------- 152.8/203.1 MB 11.3 MB/s eta 0:00:05
#    ------------------------------ -------- 156.8/203.1 MB 11.3 MB/s eta 0:00:05
#    ------------------------------ -------- 159.1/203.1 MB 11.3 MB/s eta 0:00:04
#    ------------------------------- ------- 161.5/203.1 MB 11.3 MB/s eta 0:00:04
#    ------------------------------- ------- 164.1/203.1 MB 11.3 MB/s eta 0:00:04
#    -------------------------------- ------ 167.2/203.1 MB 11.3 MB/s eta 0:00:04
#    -------------------------------- ------ 170.1/203.1 MB 11.3 MB/s eta 0:00:03
#    --------------------------------- ----- 172.5/203.1 MB 11.3 MB/s eta 0:00:03
#    --------------------------------- ----- 174.9/203.1 MB 11.3 MB/s eta 0:00:03
#    ---------------------------------- ---- 177.5/203.1 MB 11.3 MB/s eta 0:00:03
#    ---------------------------------- ---- 179.8/203.1 MB 11.3 MB/s eta 0:00:03
#    ---------------------------------- ---- 181.1/203.1 MB 11.3 MB/s eta 0:00:02
#    ----------------------------------- --- 183.2/203.1 MB 11.2 MB/s eta 0:00:02
#    ----------------------------------- --- 185.9/203.1 MB 11.2 MB/s eta 0:00:02
#    ------------------------------------ -- 188.2/203.1 MB 11.2 MB/s eta 0:00:02
#    ------------------------------------ -- 190.8/203.1 MB 11.3 MB/s eta 0:00:02
#    ------------------------------------- - 193.5/203.1 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- - 195.8/203.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------  198.2/203.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------  200.8/203.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------  202.9/203.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------  202.9/203.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------  202.9/203.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------  202.9/203.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------------- 203.1/203.1 MB 10.8 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --------------- ------------------------ 2.4/6.2 MB 9.6 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.2 MB 9.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 8.6 MB/s eta 0:00:00
# Downloading networkx-3.4.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 8.5 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    --------------------------------------- 536.2/536.2 kB 17.1 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, pdf2image, networkx, torch
# Successfully installed mpmath-1.3.0 networkx-3.4.1 pdf2image-1.17.0 sympy-1.13.1 torch-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz  
import pytesseract  
from PIL import Image
from transformers import pipeline
import io


summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    images = []

    for page_num in range(doc.page_count):
        page = doc[page_num]
        full_text += page.get_text("text")
        
        for img in page.get_images(full=True):
            xref = img[0]
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]
            images.append(Image.open(io.BytesIO(image_bytes)))

    doc.close()
    return full_text, images


def extract_text_from_images(images):
    ocr_text = ""
    for img in images:
        ocr_text += pytesseract.image_to_string(img) + "\n"
    return ocr_text

# Function to chunk the text for summarization
def chunk_text(text, max_chunk_size=1024):
    words = text.split()
    chunks = []
    current_chunk = []
    current_length = 0

    for word in words:
        current_chunk.append(word)
        current_length += len(word) + 1  # +1 for space
        if current_length >= max_chunk_size:
            chunks.append(" ".join(current_chunk))
            current_chunk = []
            current_length = 0
    
    # Add the last chunk if it has content
    if current_chunk:
        chunks.append(" ".join(current_chunk))
    
    return chunks

# Function to summarize each chunk of text
def summarize_chunks(chunks):
    summarized_text = ""
    for chunk in chunks:
        try:
            # Summarize each chunk
            summary = summarizer(chunk, max_length=150, min_length=25, do_sample=False)
            summarized_text += summary[0]['summary_text'] + " "
        except Exception as e:
            summarized_text += f"\nError in summarization: {str(e)}"
    return summarized_text

# Main function to process the uploaded PDF
def process_upload(file_path):
    try:
        # Extract text and images from the PDF
        text, images = extract_text_from_pdf(file_path)

        # Extract text from the images using OCR
        ocr_text = extract_text_from_images(images)

        # Combine text from the PDF and from OCR
        full_text = text + "\n" + ocr_text

        # Check if full_text is non-empty and large enough
        if len(full_text.strip()) == 0:
            return "No extractable text found in the PDF."

        # Chunk the text if it's too long
        chunks = chunk_text(full_text)

        # Summarize each chunk
        summary = summarize_chunks(chunks)

        return full_text, summary

    except Exception as e:
        return f"Error in processing PDF: {str(e)}", None
